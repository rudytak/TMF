# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import signal
from scipy.io import wavfile
import numpy as np

# %matplotlib widget

# %%
sample_rate, samples = wavfile.read('žbluňk2.wav')
frequencies, times, spectrogram = signal.spectrogram(samples[:,1], sample_rate, nfft=2**12)

spectrogram = np.array(spectrogram)/np.max(spectrogram)

plt.figure(figsize=(8,6))
plt.pcolormesh(times, frequencies, spectrogram, cmap="plasma")
plt.colorbar()
# plt.imshow(spectrogram)
plt.ylim(0, 500)
plt.xlim(5.05, 5.25)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.title("Sound 1 spectrogram")

plt.plot([5.09, 5.185], [80, 300], "w-.", linewidth=2)
plt.show()
plt.savefig("./imgs/ss1.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sample_rate, samples = wavfile.read('žbluňk1.wav')
frequencies, times, spectrogram = signal.spectrogram(samples[:,1], sample_rate, nfft=2**12)

spectrogram = np.array(spectrogram)/np.max(spectrogram)

plt.figure(figsize=(8,6))
plt.pcolormesh(times, frequencies, spectrogram, cmap="plasma")
plt.colorbar()
# plt.imshow(spectrogram)
plt.ylim(0, 750)
plt.xlim(0.45, 0.65)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.title("Sound 2 spectrogram")

plt.plot([0.474, 0.6], [80, 670], "w-.", linewidth=2)
plt.show()
plt.savefig("./imgs/ss2.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
