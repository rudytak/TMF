# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

lmap = lambda f,x : list(map(f, x))

xdata = []
ydata = []

samples_per_sec = 200
with open("./out.csv", "r") as read:
    # DATA
    data = read.readlines()[1:]
    data = lmap(lambda row: row.rstrip().split(","), data)

    xdata = lmap(lambda row: float(row[0]), data)
    ydata1 = lmap(lambda row: float(row[1]), data)
    ydata2 = lmap(lambda row: float(row[2]), data)

    plt.plot(xdata, ydata1)
    plt.plot(xdata, ydata2)
    
plt.figure()
plt.xlim([0.01, 1.5])
plt.ylim([-10000, 30000])
plt.plot(
    np.fft.fftfreq(len(ydata)) * 1000,
    np.fft.fft(ydata),
)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\ASUS\Desktop\TMF\23-24\10\spinners\sim\fft_analyze.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/TMF/23-24/10/spinners/sim/fft_analyze.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> plt.xlim([0.01, 1.5])
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/TMF/23-24/10/spinners/sim/fft_analyze.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> plt.ylim([-10000, 30000])
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/TMF/23-24/10/spinners/sim/fft_analyze.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> plt.plot(
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/TMF/23-24/10/spinners/sim/fft_analyze.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a>     np.fft.fftfreq(len(ydata)) * 1000,
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/TMF/23-24/10/spinners/sim/fft_analyze.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a>     np.fft.fft(ydata),
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/TMF/23-24/10/spinners/sim/fft_analyze.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a> )
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\fft\helper.py:162, in fftfreq(n, d)
#     160 if not isinstance(n, integer_types):
#     161     raise ValueError("n should be an integer")
# --> 162 val = 1.0 / (n * d)
#     163 results = empty(n, int)
#     164 N = (n-1)//2 + 1
#
# ZeroDivisionError: float division by zero
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
